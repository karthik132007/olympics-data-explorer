# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df=pd.read_csv("data\\athlete_events.csv")
noc=pd.read_csv("data\\noc_regions.csv")
df.sample(5)
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 216923  108931                   Niwatana Sesawasdi   M  19.0   155.0    50.0
# 45336    23391  Robert Thomas "Bob" Cottingham, Jr.   M  22.0   183.0    48.0
# 53288    27354                    Roberto Dellasega   M  19.0   181.0    68.0
# 110795   56042                       Marko Jovanovi   M  20.0   182.0    78.0
# 53672    27525                      Lucien Demuynck   M  20.0   180.0    69.0
#
#                  Team  NOC        Games  Year  Season         City  \
# 216923       Thailand  THA  1968 Summer  1968  Summer  Mexico City
# 45336   United States  USA  1988 Summer  1988  Summer        Seoul
# 53288           Italy  ITA  2010 Winter  2010  Winter    Vancouver
# 110795         Serbia  SRB  2008 Summer  2008  Summer      Beijing
# 53672         Belgium  BEL  1952 Summer  1952  Summer     Helsinki
#
#               Sport                                     Event Medal
# 216923     Football                   Football Men's Football   NaN
# 45336       Fencing                 Fencing Men's Sabre, Team   NaN
# 53288   Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 110795     Football                   Football Men's Football   NaN
# 53672     Athletics                Athletics Men's 800 metres   NaN
